# %%
import os
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Preprocess

# %%
directory = './csvFiles'

# %%
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

# %%
# 파일 목록을 랜덤하게 섞습니다.
random.seed(42)  # 재현 가능한 결과를 위해 시드 설정
random.shuffle(csv_files)

# %%
df_list = []
for file in csv_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)
    df = df.iloc[300:-100]
    df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
    df_list.append(df)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)
# C:\Users\admin\AppData\Local\Temp\ipykernel_35792\1545687217.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)

# %%
combined_df = pd.concat(df_list, ignore_index=True)

# %%
combined_df
# Out:
#           Frame   Time  m_avg_PelvisPosX  m_avg_PelvisPosY  m_avg_PelvisPosZ  \
# 0         301.0   3.45              0.02              0.54              0.69
# 1         302.0   3.47              0.02              0.54              0.69
# 2         303.0   3.48              0.02              0.54              0.69
# 3         304.0   3.49              0.02              0.54              0.69
# 4         305.0   3.50              0.02              0.54              0.69
# ...         ...    ...               ...               ...               ...
# 1250226  4599.0  51.25             -0.67              0.46              0.82
# 1250227  4600.0  51.26             -0.67              0.46              0.82
# 1250228  4601.0  51.27             -0.67              0.46              0.82
# 1250229  4602.0  51.28             -0.67              0.46              0.82
# 1250230  4603.0  51.29             -0.67              0.46              0.82
#
#          m_avg_PelvisRotX  m_avg_PelvisRotY  m_avg_PelvisRotZ  \
# 0                  358.82              0.68            359.84
# 1                  358.82              0.68            359.84
# 2                  358.82              0.68            359.84
# 3                  358.82              0.68            359.84
# 4                  358.82              0.68            359.84
# ...                   ...               ...               ...
# 1250226             18.55            179.77            357.66
# 1250227             18.36            179.61            357.62
# 1250228             18.36            179.61            357.62
# 1250229             18.36            179.61            357.62
# 1250230             18.45            179.67            357.49
#
#          m_avg_L_HipPosX  m_avg_L_HipPosY  ...  m_avg_R_ElbowRotX  \
# 0                  -0.04             0.46  ...               8.26
# 1                  -0.04             0.46  ...               8.27
# 2                  -0.04             0.46  ...               8.27
# 3                  -0.04             0.46  ...               8.27
# 4                  -0.04             0.46  ...               8.26
# ...                  ...              ...  ...                ...
# 1250226            -0.61             0.39  ...              11.13
# 1250227            -0.61             0.39  ...              11.13
# 1250228            -0.61             0.39  ...              11.13
# 1250229            -0.61             0.39  ...              11.14
# 1250230            -0.61             0.39  ...              11.14
#
#          m_avg_R_ElbowRotY  m_avg_R_ElbowRotZ  m_avg_R_WristPosX  \
# 0                   352.22             350.74               0.73
# 1                   352.27             350.77               0.73
# 2                   352.29             350.81               0.73
# 3                   352.28             350.81               0.73
# 4                   352.23             350.85               0.73
# ...                    ...                ...                ...
# 1250226             198.30               3.76              -1.32
# 1250227             198.37               3.79              -1.32
# 1250228             198.42               3.84              -1.32
# 1250229             198.47               3.87              -1.32
# 1250230             198.51               3.90              -1.32
#
#          m_avg_R_WristPosY  m_avg_R_WristPosZ  m_avg_R_WristRotX  \
# 0                     0.94               0.63               0.20
# 1                     0.94               0.63               0.11
# 2                     0.94               0.63               0.15
# 3                     0.94               0.63               0.24
# 4                     0.94               0.63               0.39
# ...                    ...                ...                ...
# 1250226               1.04               0.93              47.17
# 1250227               1.04               0.92              47.21
# 1250228               1.04               0.92              47.29
# 1250229               1.04               0.92              47.36
# 1250230               1.04               0.93              47.44
#
#          m_avg_R_WristRotY  m_avg_R_WristRotZ  Unnamed: 128
# 0                   359.56               0.85           NaN
# 1                   359.54               0.88           NaN
# 2                   359.53               0.92           NaN
# 3                   359.54               0.96           NaN
# 4                   359.57               0.96           NaN
# ...                    ...                ...           ...
# 1250226              37.40             178.72           NaN
# 1250227              37.33             178.62           NaN
# 1250228              37.23             178.46           NaN
# 1250229              37.14             178.29           NaN
# 1250230              37.06             178.13           NaN
#
# [1250231 rows x 129 columns]

# %%
len(combined_df)
# Out:
# 1250231

# %%
rotation_columns_pos = [col for col in combined_df.columns if 'Pos' in col]
rotation_df_pos = combined_df[rotation_columns_pos]

# %%
rotation_df_pos.head()
# Out:
#    m_avg_PelvisPosX  m_avg_PelvisPosY  m_avg_PelvisPosZ  m_avg_L_HipPosX  \
# 0              0.02              0.54              0.69            -0.04
# 1              0.02              0.54              0.69            -0.04
# 2              0.02              0.54              0.69            -0.04
# 3              0.02              0.54              0.69            -0.04
# 4              0.02              0.54              0.69            -0.04
#
#    m_avg_L_HipPosY  m_avg_L_HipPosZ  m_avg_L_KneePosX  m_avg_L_KneePosY  \
# 0             0.46             0.67             -0.08              0.07
# 1             0.46             0.67             -0.08              0.07
# 2             0.46             0.67             -0.08              0.07
# 3             0.46             0.67             -0.08              0.07
# 4             0.46             0.67             -0.08              0.07
#
#    m_avg_L_KneePosZ  m_avg_L_AnklePosX  ...  m_avg_R_CollarPosZ  \
# 0              0.68              -0.07  ...                0.65
# 1              0.68              -0.07  ...                0.65
# 2              0.68              -0.07  ...                0.65
# 3              0.68              -0.07  ...                0.65
# 4              0.68              -0.07  ...                0.65
#
#    m_avg_R_ShoulderPosX  m_avg_R_ShoulderPosY  m_avg_R_ShoulderPosZ  \
# 0                  0.21                  1.02                  0.64
# 1                  0.21                  1.02                  0.64
# 2                  0.21                  1.02                  0.64
# 3                  0.21                  1.02                  0.64
# 4                  0.21                  1.02                  0.64
#
#    m_avg_R_ElbowPosX  m_avg_R_ElbowPosY  m_avg_R_ElbowPosZ  m_avg_R_WristPosX  \
# 0               0.47               0.98               0.61               0.73
# 1               0.47               0.98               0.61               0.73
# 2               0.47               0.98               0.61               0.73
# 3               0.47               0.98               0.61               0.73
# 4               0.47               0.98               0.61               0.73
#
#    m_avg_R_WristPosY  m_avg_R_WristPosZ
# 0               0.94               0.63
# 1               0.94               0.63
# 2               0.94               0.63
# 3               0.94               0.63
# 4               0.94               0.63
#
# [5 rows x 63 columns]

# %%
rotation_columns_rot = [col for col in combined_df.columns if 'Rot' in col]
rotation_df_rot = combined_df[rotation_columns_rot]

# %%
# -180~180 사이로 정규화
normalize_angle = lambda x: (x - 360) if x > 180 else (x + 360) if x < -180 else x
rotation_df_rot = rotation_df_rot.apply(lambda col: col.apply(normalize_angle))

# %%
rotation_df_rot.head()
# Out:
#    m_avg_PelvisRotX  m_avg_PelvisRotY  m_avg_PelvisRotZ  m_avg_L_HipRotX  \
# 0             -1.18              0.68             -0.16            -0.28
# 1             -1.18              0.68             -0.16            -0.28
# 2             -1.18              0.68             -0.16            -0.28
# 3             -1.18              0.68             -0.16            -0.28
# 4             -1.18              0.68             -0.16            -0.28
#
#    m_avg_L_HipRotY  m_avg_L_HipRotZ  m_avg_L_KneeRotX  m_avg_L_KneeRotY  \
# 0             0.11            -0.02             -0.93              0.18
# 1             0.11            -0.02             -0.93              0.18
# 2             0.11            -0.02             -0.93              0.18
# 3             0.11            -0.02             -0.93              0.18
# 4             0.11            -0.02             -0.93              0.18
#
#    m_avg_L_KneeRotZ  m_avg_L_AnkleRotX  ...  m_avg_R_CollarRotZ  \
# 0             -0.09               0.04  ...                 1.8
# 1             -0.09               0.04  ...                 1.8
# 2             -0.09               0.04  ...                 1.8
# 3             -0.09               0.04  ...                 1.8
# 4             -0.09               0.04  ...                 1.8
#
#    m_avg_R_ShoulderRotX  m_avg_R_ShoulderRotY  m_avg_R_ShoulderRotZ  \
# 0                  9.14                 -0.34                 -6.66
# 1                  9.14                 -0.35                 -6.63
# 2                  9.13                 -0.37                 -6.61
# 3                  9.12                 -0.39                 -6.62
# 4                  9.12                 -0.35                 -6.60
#
#    m_avg_R_ElbowRotX  m_avg_R_ElbowRotY  m_avg_R_ElbowRotZ  m_avg_R_WristRotX  \
# 0               8.26              -7.78              -9.26               0.20
# 1               8.27              -7.73              -9.23               0.11
# 2               8.27              -7.71              -9.19               0.15
# 3               8.27              -7.72              -9.19               0.24
# 4               8.26              -7.77              -9.15               0.39
#
#    m_avg_R_WristRotY  m_avg_R_WristRotZ
# 0              -0.44               0.85
# 1              -0.46               0.88
# 2              -0.47               0.92
# 3              -0.46               0.96
# 4              -0.43               0.96
#
# [5 rows x 63 columns]

# %%
# 이전 프레임과의 차이를 계산하여 변화량 DataFrame을 생성
# rotation_change_df = rotation_df.diff().abs()

# %%
# # 평균 변화량을 계산하는 함수
# def calculate_average_change(rotation_df):
#     rotation_change_df = rotation_df.diff().abs()
#     # 첫 번째 행의 NaN 값을 0으로 채우기 (또는 다른 합리적인 값으로 채울 수 있음)
#     rotation_change_df.iloc[0] = rotation_change_df.iloc[0].fillna(0)
#     # 모든 joint의 변화량에 대한 평균을 계산
#     average_change = rotation_change_df.mean(axis=1)
#     return average_change

# %%
# # 평균 변화량을 기준으로 데이터를 1, 2, 3단계로 나누는 함수
# def categorize_average_change(average_change, thresholds):
#     # 변화량에 따라 범주화
#     categories = np.digitize(average_change, thresholds)
#     return categories

# %%
# # DataFrame에 변화량 범주를 추가하는 함수
# def add_change_category_to_df(rotation_df, thresholds):
#     average_change = calculate_average_change(rotation_df)
#     change_categories = categorize_average_change(average_change, thresholds)
#     rotation_df['Rot_diff_category'] = change_categories
#     return rotation_df

# %%
# # 임계값 설정 (예: [5, 10])
# thresholds = [5, 10]
# combined_df = add_change_category_to_df(rotation_df, thresholds)

# %%
# rotation_df_rot에 -180 ~ 180 범위를 벗어나는 값이 있는지 확인
num_values_out_of_range = (rotation_df_rot > 180).sum().sum() + (rotation_df_rot < -180).sum().sum()

# 결과 확인
if num_values_out_of_range > 0:
    print(f"범위를 벗어나는 값의 수: {num_values_out_of_range}")
else:
    print("범위를 벗어나는 값이 없습니다.")
# Out:
# 범위를 벗어나는 값이 없습니다.

# %%
# category_counts = combined_df['Rot_diff_category'].value_counts()
# print(category_counts)

# %%
rotation_df_rot.head()
# Out:
#    m_avg_PelvisRotX  m_avg_PelvisRotY  m_avg_PelvisRotZ  m_avg_L_HipRotX  \
# 0             -1.18              0.68             -0.16            -0.28
# 1             -1.18              0.68             -0.16            -0.28
# 2             -1.18              0.68             -0.16            -0.28
# 3             -1.18              0.68             -0.16            -0.28
# 4             -1.18              0.68             -0.16            -0.28
#
#    m_avg_L_HipRotY  m_avg_L_HipRotZ  m_avg_L_KneeRotX  m_avg_L_KneeRotY  \
# 0             0.11            -0.02             -0.93              0.18
# 1             0.11            -0.02             -0.93              0.18
# 2             0.11            -0.02             -0.93              0.18
# 3             0.11            -0.02             -0.93              0.18
# 4             0.11            -0.02             -0.93              0.18
#
#    m_avg_L_KneeRotZ  m_avg_L_AnkleRotX  ...  m_avg_R_CollarRotZ  \
# 0             -0.09               0.04  ...                 1.8
# 1             -0.09               0.04  ...                 1.8
# 2             -0.09               0.04  ...                 1.8
# 3             -0.09               0.04  ...                 1.8
# 4             -0.09               0.04  ...                 1.8
#
#    m_avg_R_ShoulderRotX  m_avg_R_ShoulderRotY  m_avg_R_ShoulderRotZ  \
# 0                  9.14                 -0.34                 -6.66
# 1                  9.14                 -0.35                 -6.63
# 2                  9.13                 -0.37                 -6.61
# 3                  9.12                 -0.39                 -6.62
# 4                  9.12                 -0.35                 -6.60
#
#    m_avg_R_ElbowRotX  m_avg_R_ElbowRotY  m_avg_R_ElbowRotZ  m_avg_R_WristRotX  \
# 0               8.26              -7.78              -9.26               0.20
# 1               8.27              -7.73              -9.23               0.11
# 2               8.27              -7.71              -9.19               0.15
# 3               8.27              -7.72              -9.19               0.24
# 4               8.26              -7.77              -9.15               0.39
#
#    m_avg_R_WristRotY  m_avg_R_WristRotZ
# 0              -0.44               0.85
# 1              -0.46               0.88
# 2              -0.47               0.92
# 3              -0.46               0.96
# 4              -0.43               0.96
#
# [5 rows x 63 columns]

# %%
rotation_df_pos.to_csv('./rotation_df_pos.csv', index=False)
rotation_df_rot.to_csv('./rotation_df_rot.csv', index=False)

# %%
# 변환된 데이터를 DataFrame으로 변환
rotation_df_pos = pd.DataFrame(rotation_df_pos, columns=rotation_df_pos.columns)
rotation_df_rot = pd.DataFrame(rotation_df_rot, columns=rotation_df_rot.columns)

# %% [markdown]
# ## Train, Test set 나누기

# %% [markdown]
# ### rotation_df_pose train, test

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.model_selection import train_test_split

# %%
train_pos = rotation_df_pos.iloc[:897757]
test_rot = rotation_df_pos.iloc[897757:]

# %%
X_train, X_val = train_test_split(train_pos, test_size=0.2, random_state=42, shuffle=False)

# %%
batch_size = 128
n_input = 30  # Sequence length
n_features = 63  # Number of features
output_units = (21 * 3)  # Output shape
head_size = 320  # Size of attention head
num_heads = 8  # Number of attention heads
ff_dim = 512  # Hidden layer size in feed forward network inside transformer
num_blocks = 4  # Number of transformer blocks
mlp_units = [512, 256, 128]  # Size of the dense layers of the final classifier
dropout_rate = 0.3 

# TimeseriesGenerator 생성
train_generator_pos = TimeseriesGenerator(X_train.values, X_train.values, length=n_input, batch_size=batch_size)
val_generator_pos = TimeseriesGenerator(X_val.values, X_val.values, length=n_input, batch_size=batch_size)

# %%
train_generator_pos.length
# Out:
# 30

# %%
X, y = train_generator_pos[0]

# %%
X.shape
# Out:
# (128, 30, 63)

# %%
y.shape
# Out:
# (128, 63)

# %%
y
# Out:
# array([[0.03, 0.54, 0.69, ..., 0.73, 0.94, 0.63],
#        [0.03, 0.54, 0.69, ..., 0.73, 0.94, 0.63],
#        [0.03, 0.54, 0.69, ..., 0.73, 0.94, 0.63],
#        ...,
#        [0.01, 0.55, 0.69, ..., 0.11, 0.73, 0.83],
#        [0.01, 0.55, 0.69, ..., 0.11, 0.73, 0.83],
#        [0.01, 0.55, 0.69, ..., 0.11, 0.73, 0.83]])

# %% [markdown]
# # Training

# %% [markdown]
# ## Seketal position learning (CNN)

# %%
import tensorflow as tf
from keras.models import Sequential
from keras import layers
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Reshape, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.initializers import HeNormal
from keras.optimizers import Adam
from keras.losses import Loss

# %%
model = Sequential()

def build_skeleton_cnn_model(input_shape):
    model = Sequential()
    
    # 첫 번째 컨볼루션 레이어
    model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))

    # 두 번째 컨볼루션 레이어
    model.add(Conv1D(filters=128, kernel_size=2, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    # 평탄화 및 완전 연결 레이어
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))

    # 출력층
    model.add(Dense(output_units))  # output_units는 예측하고자 하는 출력 값의 개수

    return model

# 모델 인스턴스 생성
input_shape = (n_input, n_features)  # n_input: 시간 단계의 수, n_features: 각 시간 단계에서의 특성 수
output_units = output_units  # 예: 21개 관절 각각에 대한 x, y, z 위치
cnn_model = build_skeleton_cnn_model(input_shape)

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)  # patience를 7에서 15로 증가
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, min_lr=0.00001)  # patience를 4에서 7로 증가, min_lr를 더 낮춤
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
csv_logger = CSVLogger('training_log.csv', append=True)

# 모델 요약 출력
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 29, 64)            8128
#
#  max_pooling1d (MaxPooling1D  (None, 14, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 13, 128)           16512
#
#  max_pooling1d_1 (MaxPooling  (None, 6, 128)           0
#  1D)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 100)               76900
#
#  dense_1 (Dense)             (None, 63)                6363
#
# =================================================================
# Total params: 107,903
# Trainable params: 107,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
# cnn_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
cnn_model.compile(optimizer=Adam(learning_rate=0.0001, decay=1e-6), loss='mean_squared_error', metrics=['accuracy'])

# %%
# 사용 가능한 GPU 목록을 출력합니다.
print("Available GPUs:", tf.config.experimental.list_physical_devices('GPU'))

# 현재 장치를 출력합니다.
print("Current device:", tf.test.gpu_device_name())
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Current device: /device:GPU:0

# %%
cnn_model.fit(
    train_generator_pos, 
    epochs=50,  
    validation_data=val_generator_pos,
    callbacks=[early_stopping, reduce_lr, model_checkpoint, csv_logger]
    )
# Out:
# Epoch 1/50
# 5611/5611 [==============================] - 15s 2ms/step - loss: 0.0158 - accuracy: 0.4247 - val_loss: 0.0054 - val_accuracy: 0.5187 - lr: 1.0000e-04
# Epoch 2/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0043 - accuracy: 0.6311 - val_loss: 0.0035 - val_accuracy: 0.6356 - lr: 1.0000e-04
# Epoch 3/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0032 - accuracy: 0.7071 - val_loss: 0.0029 - val_accuracy: 0.6659 - lr: 1.0000e-04
# Epoch 4/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0027 - accuracy: 0.7352 - val_loss: 0.0024 - val_accuracy: 0.6982 - lr: 1.0000e-04
# Epoch 5/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0024 - accuracy: 0.7507 - val_loss: 0.0032 - val_accuracy: 0.6997 - lr: 1.0000e-04
# Epoch 6/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0022 - accuracy: 0.7624 - val_loss: 0.0021 - val_accuracy: 0.7009 - lr: 1.0000e-04
# Epoch 7/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0021 - accuracy: 0.7747 - val_loss: 0.0029 - val_accuracy: 0.7225 - lr: 1.0000e-04
# Epoch 8/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0019 - accuracy: 0.7821 - val_loss: 0.0020 - val_accuracy: 0.7476 - lr: 1.0000e-04
# Epoch 9/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0018 - accuracy: 0.7923 - val_loss: 0.0018 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 10/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0017 - accuracy: 0.7970 - val_loss: 0.0019 - val_accuracy: 0.7759 - lr: 1.0000e-04
# Epoch 11/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0017 - accuracy: 0.8010 - val_loss: 0.0016 - val_accuracy: 0.7406 - lr: 1.0000e-04
# Epoch 12/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0016 - accuracy: 0.8045 - val_loss: 0.0016 - val_accuracy: 0.7661 - lr: 1.0000e-04
# Epoch 13/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0016 - accuracy: 0.8105 - val_loss: 0.0014 - val_accuracy: 0.7862 - lr: 1.0000e-04
# Epoch 14/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0015 - accuracy: 0.8114 - val_loss: 0.0014 - val_accuracy: 0.7841 - lr: 1.0000e-04
# Epoch 15/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0015 - accuracy: 0.8171 - val_loss: 0.0014 - val_accuracy: 0.7929 - lr: 1.0000e-04
# Epoch 16/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0015 - accuracy: 0.8174 - val_loss: 0.0015 - val_accuracy: 0.7912 - lr: 1.0000e-04
# Epoch 17/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0014 - accuracy: 0.8216 - val_loss: 0.0013 - val_accuracy: 0.7894 - lr: 1.0000e-04
# Epoch 18/50
# 5611/5611 [==============================] - 14s 2ms/step - loss: 0.0014 - accuracy: 0.8269 - val_loss: 0.0015 - val_accuracy: 0.8006 - lr: 1.0000e-04
# Epoch 19/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0014 - accuracy: 0.8252 - val_loss: 0.0014 - val_accuracy: 0.8044 - lr: 1.0000e-04
# Epoch 20/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0014 - accuracy: 0.8282 - val_loss: 0.0013 - val_accuracy: 0.8064 - lr: 1.0000e-04
# Epoch 21/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0013 - accuracy: 0.8310 - val_loss: 0.0014 - val_accuracy: 0.8025 - lr: 1.0000e-04
# Epoch 22/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0013 - accuracy: 0.8315 - val_loss: 0.0013 - val_accuracy: 0.8092 - lr: 1.0000e-04
# Epoch 23/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0013 - accuracy: 0.8343 - val_loss: 0.0012 - val_accuracy: 0.8102 - lr: 1.0000e-04
# Epoch 24/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0013 - accuracy: 0.8354 - val_loss: 0.0012 - val_accuracy: 0.8196 - lr: 1.0000e-04
# Epoch 25/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8548 - val_loss: 0.0011 - val_accuracy: 0.8287 - lr: 2.0000e-05
# Epoch 26/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8553 - val_loss: 0.0011 - val_accuracy: 0.8238 - lr: 2.0000e-05
# Epoch 27/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8556 - val_loss: 0.0011 - val_accuracy: 0.8279 - lr: 2.0000e-05
# Epoch 28/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8554 - val_loss: 0.0011 - val_accuracy: 0.8217 - lr: 2.0000e-05
# Epoch 29/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8565 - val_loss: 0.0011 - val_accuracy: 0.8308 - lr: 2.0000e-05
# Epoch 30/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8575 - val_loss: 0.0011 - val_accuracy: 0.8368 - lr: 2.0000e-05
# Epoch 31/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8584 - val_loss: 0.0011 - val_accuracy: 0.8289 - lr: 2.0000e-05
# Epoch 32/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8578 - val_loss: 0.0011 - val_accuracy: 0.8359 - lr: 2.0000e-05
# Epoch 33/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8612 - val_loss: 0.0011 - val_accuracy: 0.8337 - lr: 1.0000e-05
# Epoch 34/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8616 - val_loss: 0.0011 - val_accuracy: 0.8332 - lr: 1.0000e-05
# Epoch 35/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8607 - val_loss: 0.0011 - val_accuracy: 0.8292 - lr: 1.0000e-05
# Epoch 36/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8616 - val_loss: 0.0011 - val_accuracy: 0.8346 - lr: 1.0000e-05
# Epoch 37/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8619 - val_loss: 0.0011 - val_accuracy: 0.8361 - lr: 1.0000e-05
# Epoch 38/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8623 - val_loss: 0.0011 - val_accuracy: 0.8302 - lr: 1.0000e-05
# Epoch 39/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8625 - val_loss: 0.0011 - val_accuracy: 0.8346 - lr: 1.0000e-05
# Epoch 40/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8627 - val_loss: 0.0011 - val_accuracy: 0.8321 - lr: 1.0000e-05
# Epoch 41/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8625 - val_loss: 0.0010 - val_accuracy: 0.8374 - lr: 1.0000e-05
# Epoch 42/50
# 5611/5611 [==============================] - 15s 3ms/step - loss: 0.0011 - accuracy: 0.8629 - val_loss: 0.0011 - val_accuracy: 0.8264 - lr: 1.0000e-05
# Epoch 43/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8624 - val_loss: 0.0010 - val_accuracy: 0.8375 - lr: 1.0000e-05
# Epoch 44/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8636 - val_loss: 0.0011 - val_accuracy: 0.8344 - lr: 1.0000e-05
# Epoch 45/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8629 - val_loss: 0.0010 - val_accuracy: 0.8315 - lr: 1.0000e-05
# Epoch 46/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8644 - val_loss: 0.0010 - val_accuracy: 0.8325 - lr: 1.0000e-05
# Epoch 47/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8635 - val_loss: 0.0010 - val_accuracy: 0.8406 - lr: 1.0000e-05
# Epoch 48/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8642 - val_loss: 0.0010 - val_accuracy: 0.8372 - lr: 1.0000e-05
# Epoch 49/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8645 - val_loss: 0.0010 - val_accuracy: 0.8385 - lr: 1.0000e-05
# Epoch 50/50
# 5611/5611 [==============================] - 14s 3ms/step - loss: 0.0011 - accuracy: 0.8649 - val_loss: 0.0010 - val_accuracy: 0.8331 - lr: 1.0000e-05

# %%
myloss = cnn_model.history.history['loss']
# acc = cnn_model.history.history['accuracy']
myval_loss = cnn_model.history.history['val_loss']
plt.plot(range(len(myloss)),myloss, label='Training Loss', color='blue')
# plt.plot(range(len(acc)),acc, label='Accuracy', color='red')
plt.plot(range(len(myval_loss)), myval_loss, label='Validation Loss', color = 'orange')

# %%
# CNN 모델의 마지막 컨볼루션 레이어 출력을 얻는 모델
# 여기서 '1'은 두 번째 컨볼루션 레이어를 가리킴 (인덱스는 0부터 시작)
cnn_feature_model = tf.keras.Model(inputs=cnn_model.input, outputs=cnn_model.layers[3].output)

# %%
cnn_feature_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_input (InputLayer)   [(None, 30, 63)]          0
#
#  conv1d (Conv1D)             (None, 29, 64)            8128
#
#  max_pooling1d (MaxPooling1D  (None, 14, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 13, 128)           16512
#
#  max_pooling1d_1 (MaxPooling  (None, 6, 128)           0
#  1D)
#
# =================================================================
# Total params: 24,640
# Trainable params: 24,640
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Sequential rotation learning (RNN)

# %%
train_rot = combined_df.iloc[:897757]
test_rot = combined_df.iloc[897757:]

# %%
batch_size = 128
n_input = 30  # Sequence length
n_features = 63  # Number of features
output_units = (21 * 3) + 1  # Output shape
head_size = 320  # Size of attention head
num_heads = 8  # Number of attention heads
ff_dim = 512  # Hidden layer size in feed forward network inside transformer
num_blocks = 4  # Number of transformer blocks
mlp_units = [512, 256, 128]  # Size of the dense layers of the final classifier
dropout_rate = 0.3 

# TimeseriesGenerator 생성
train_generator_rot = TimeseriesGenerator(X_train.values, X_train.values, length=n_input, batch_size=batch_size)
val_generator_rot = TimeseriesGenerator(X_val.values, X_val.values, length=n_input, batch_size=batch_size)

# %%
X_train, X_val = train_test_split(train_rot, test_size=0.2, random_state=42, shuffle=False)

# %%
train_generator_rot.length
# Out:
# 30

# %%
X, y = train_generator_rot[0]

# %%
X.shape
# Out:
# (128, 30, 63)

# %%
y.shape
# Out:
# (128, 63)

# %%
# 훈련 데이터셋에서 특징 추출
train_features = cnn_feature_model.predict(X_train)

# 검증 데이터셋에서 특징 추출
val_features = cnn_feature_model.predict(X_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 # 훈련 데이터셋에서 특징 추출
# ----> 2 train_features = cnn_feature_model.predict(X_train)
#       4 # 검증 데이터셋에서 특징 추출
#       5 val_features = cnn_feature_model.predict(X_val)
#
# File c:\Users\admin\anaconda3\envs\ihsens\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file6uewjvn4.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\admin\anaconda3\envs\ihsens\lib\site-packages\keras\engine\training.py", line 2041, in predict_function  *
#         return step_function(self, iterator)
#     File "c:\Users\admin\anaconda3\envs\ihsens\lib\site-packages\keras\engine\training.py", line 2027, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\admin\anaconda3\envs\ihsens\lib\site-packages\keras\engine\training.py", line 2015, in run_step  **
#         outputs = model.predict_step(data)
#     File "c:\Users\admin\anaconda3\envs\ihsens\lib\site-packages\keras\engine\training.py", line 1983, in predict_step
#         return self(x, training=False)
#     File "c:\Users\admin\anaconda3\envs\ihsens\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\admin\anaconda3\envs\ihsens\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model_1" is incompatible with the layer: expected shape=(None, 30, 63), found shape=(None, 129)

# %%
model = Sequential()

def positional_encoding(input_shape):
    n_steps, n_features = input_shape
    pos_enc = np.zeros((n_steps, n_features))
    for pos in range(n_steps):
        for i in range(n_features):
            if i % 2 == 0:
                pos_enc[pos, i] = np.sin(pos / (10000 ** ((2 * i) / n_features)))
            else:
                pos_enc[pos, i] = np.cos(pos / (10000 ** ((2 * (i - 1)) / n_features)))
    return pos_enc

def transformer_block(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-Head Attention
    attention_out =layers. MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    attention_out = Dropout(dropout)(attention_out)
    attention_out = layers.LayerNormalization(epsilon=1e-6)(inputs + attention_out)

    # Feed Forward
    ff_out = Dense(ff_dim, activation="relu", kernel_initializer=HeNormal())(attention_out)
    ff_out = Dropout(dropout)(ff_out)
    ff_out = Dense(inputs.shape[-1])(ff_out)
    ff_out = layers.LayerNormalization(epsilon=1e-6)(attention_out + ff_out)
    return ff_out

def build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_blocks, output_units, dropout=0, mlp_units=[]):
    inputs = layers.Input(shape=input_shape)
    
    # Add positional encoding
    pos_enc = positional_encoding(input_shape)
    x = inputs + pos_enc

    # Add one more transformer block
    num_blocks += 1

    for _ in range(num_blocks):
        x = transformer_block(x, head_size, num_heads, ff_dim, dropout)

    for units in mlp_units:
        x = Dense(units, activation="relu")(x)
        x = Dropout(dropout)(x)
        x = layers.LayerNormalization()(x)

    x = layers.GlobalAveragePooling1D()(x)
    outputs = Dense(output_units, activation="linear")(x)  # Change to sigmoid if needed
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# Building the model
model = build_transformer_model(
    input_shape=(n_input, n_features),
    head_size=head_size,
    num_heads=num_heads,
    ff_dim=ff_dim,
    num_blocks=num_blocks,
    dropout=dropout_rate,
    mlp_units=mlp_units,
    output_units=output_units
)

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)  # patience를 7에서 15로 증가
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, min_lr=0.00001)  # patience를 4에서 7로 증가, min_lr를 더 낮춤
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
csv_logger = CSVLogger('training_log.csv', append=True)

# %%
class CustomLoss(Loss):
    def __init__(self, weighted_columns_indices, weight_for_weighted_columns, weights_for_rot_diff_category, **kwargs):
    # def __init__(self, weighted_columns_indices, weight_for_weighted_columns, **kwargs):
        super().__init__(**kwargs)
        self.weighted_columns_indices = tf.constant(weighted_columns_indices, dtype=tf.int32)
        self.weight_for_weighted_columns = weight_for_weighted_columns
        self.weights_for_rot_diff_category = tf.constant(weights_for_rot_diff_category, dtype=tf.float32)

    def call(self, y_true, y_pred):
        # y_pred의 마지막 feature를 rot_diff_category로 분리
        y_pred_values = y_pred[:, :-1]
        # rot_diff_pred = y_pred[:, -1]

        # 런타임에 형태 확인
        # tf.print("y_true shape:", tf.shape(y_true))
        # tf.print("y_pred_values shape:", tf.shape(y_pred_values))

        # MSE 계산
        mse = tf.reduce_mean(tf.square(y_true[:, :-1] - y_pred_values), axis=-1)

        # 특정 joint rotation에 대한 가중치 적용
        weighted_mse = tf.gather(y_pred_values, self.weighted_columns_indices, axis=1)
        weighted_mse = tf.square(weighted_mse) * self.weight_for_weighted_columns
        mse += tf.reduce_mean(weighted_mse, axis=-1)

        # rot_diff_category에 따른 가중치 적용
        for category in range(len(self.weights_for_rot_diff_category)):
            category_mask = tf.cast(tf.equal(rot_diff_pred, category), tf.float32)
            category_mask = tf.expand_dims(category_mask, -1)  
            weighted_mse = tf.square(y_true[:, :-1] - y_pred_values) * category_mask
            mse += self.weights_for_rot_diff_category[category] * tf.reduce_mean(weighted_mse, axis=-1)

        return mse

# 가중치를 적용할 열 인덱스와 가중치 값
weighted_columns_indices = [42, 43, 44, 48, 49, 50, 60, 61, 62]  # 예시 인덱스
weight_for_weighted_columns = 2.0
weights_for_rot_diff_category = [1.0, 1.5, 2.0]  # 1단계, 2단계, 3단계에 대한 가중치

# CustomLoss 인스턴스 생성
custom_loss_instance = CustomLoss(
    weighted_columns_indices=weighted_columns_indices,
    weight_for_weighted_columns=weight_for_weighted_columns,
    weights_for_rot_diff_category=weights_for_rot_diff_category
)

# %%
# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.0001, decay=1e-6), loss=custom_loss_instance)
# model.compile(optimizer="adam", loss="mean_squared_error")

# %%
model.summary()

# %%
# 사용 가능한 GPU 목록을 출력합니다.
print("Available GPUs:", tf.config.experimental.list_physical_devices('GPU'))

# 현재 장치를 출력합니다.
print("Current device:", tf.test.gpu_device_name())

# %%
model.fit(
    train_generator_rot, 
    epochs=50, 
    validation_data=val_generator_rot,
    callbacks=[early_stopping, reduce_lr, model_checkpoint, csv_logger]
    # callbacks=[reduce_lr, model_checkpoint, csv_logger]
    )

# %%
model.save('final_model_Transformer.h5')

# %%
myloss = model.history.history['loss']
myval_loss = model.history.history['val_loss']
plt.plot(range(len(myloss)),myloss, label='Training Loss', color='blue')
plt.plot(range(len(myval_loss)), myval_loss, label='Validation Loss', color = 'orange')

# %% [markdown]
# # Test with real data

# %%
test_df = pd.read_csv('./B01_TransformData_FinalAvatar_20230922_171230.csv').iloc[300:-100]

# %%
test_df.head()

# %%
test_rotation_columns = [col for col in test_df.columns if 'Rot' in col]
test_rotation_df = test_df[test_rotation_columns]

# %%
test_rotation_df

# %%
#-180~180 사이로 정규화
def normalize_angle(x):
    x = np.where(x > 180, x - 360, x)
    x = np.where(x < -180, x + 360, x)
    return x
test_df[test_rotation_columns] = test_df[test_rotation_columns].applymap(normalize_angle)

# %%
test_df = test_df[test_rotation_columns].map(lambda x: float(f"{x:.2f}") if isinstance(x, (int, float)) else x)

# %%
test_df

# %%
# -180 ~ 180 범위를 벗어나는 값이 있는지 확인
num_values_out_of_range = (test_df > 180).sum().sum() + (test_df < -180).sum().sum()

# 결과 확인
if num_values_out_of_range > 0:
    print(f"범위를 벗어나는 값의 수: {num_values_out_of_range}")
else:
    print("범위를 벗어나는 값이 없습니다.")

# %%
# 평균 변화량 계산 및 범주화
def calculate_average_change(test_df):
    rotation_change_df = test_df.diff().abs()
    rotation_change_df.iloc[0] = rotation_change_df.iloc[0].fillna(0)
    average_change = rotation_change_df.mean(axis=1)
    return average_change

# %%
def categorize_average_change(average_change, thresholds):
    categories = np.digitize(average_change, thresholds)
    return categories

# %%
# 테스트 데이터에 변화량 범주 추가
def add_change_category_to_df(test_df, thresholds):
    average_change = calculate_average_change(test_df)
    change_categories = categorize_average_change(average_change, thresholds)
    test_df['Rot_diff_category'] = change_categories
    return test_df

# %%
thresholds = [5, 10]
test_df = add_change_category_to_df(test_df, thresholds)

# %%
test_df.shape

# %%
# 결과를 새로운 CSV 파일로 저장합니다.
test_df.to_csv('./test_df.csv', index=False)

# %%
# 예측 값을 넣을 빈 리스트
test_predictions = []

# 훈련 데이터셋에서 마지막 입력 개수의 값을 가져온 후
current_batch = test_df[-n_input:].to_numpy().reshape((1, n_input, n_features))

# 예측 과정 반복
for i in range(1):
    # 현재 배치에서 다음 포인트를 예측
    current_pred = model.predict(current_batch)[0]  # 마지막 시퀀스 포인트 예측
    current_pred = np.array([normalize_angle(y) for y in current_pred])  # 예측값 정규화

    # 예측된 마지막 프레임을 리스트에 추가
    test_predictions.append(current_pred)

    # 새로운 배치 생성: 마지막 시퀀스 제외하고 예측값 추가
    current_batch = np.roll(current_batch, -1, axis=1)
    current_batch[0, -1, :] = current_pred

# %%
test_predictions

# %%
print(test_predictions[0].shape)

# %%
test_predictions_array = np.array(test_predictions)

# %%
print(test_predictions_array.shape)

# %%
# test_predictions 리스트의 각 항목을 (64,) 모양의 배열로 변환합니다.
# test_predictions_flat = [pred.flatten() for pred in test_predictions]

# 변환된 리스트를 데이터프레임으로 변환합니다.
test_predictions = pd.DataFrame(test_predictions_array)

# test_predictions 데이터프레임을 CSV 파일로 저장합니다.
test_predictions.to_csv('./test_predictions.csv', index=True)

# %%
test_predictions

# %%
column_order = [
    'm_avg_PelvisRotX', 'm_avg_PelvisRotY', 'm_avg_PelvisRotZ',
    'm_avg_L_HipRotX', 'm_avg_L_HipRotY', 'm_avg_L_HipRotZ',
    'm_avg_L_KneeRotX', 'm_avg_L_KneeRotY', 'm_avg_L_KneeRotZ',
    'm_avg_L_AnkleRotX', 'm_avg_L_AnkleRotY', 'm_avg_L_AnkleRotZ',
    'm_avg_L_FootRotX', 'm_avg_L_FootRotY', 'm_avg_L_FootRotZ',
    'm_avg_R_HipRotX', 'm_avg_R_HipRotY', 'm_avg_R_HipRotZ',
    'm_avg_R_KneeRotX', 'm_avg_R_KneeRotY', 'm_avg_R_KneeRotZ',
    'm_avg_R_AnkleRotX', 'm_avg_R_AnkleRotY', 'm_avg_R_AnkleRotZ',
    'm_avg_R_FootRotX', 'm_avg_R_FootRotY', 'm_avg_R_FootRotZ',
    'm_avg_Spine1RotX', 'm_avg_Spine1RotY', 'm_avg_Spine1RotZ',
    'm_avg_Spine2RotX', 'm_avg_Spine2RotY', 'm_avg_Spine2RotZ',
    'm_avg_L_CollarRotX', 'm_avg_L_CollarRotY', 'm_avg_L_CollarRotZ',
    'm_avg_L_ShoulderRotX', 'm_avg_L_ShoulderRotY', 'm_avg_L_ShoulderRotZ',
    'm_avg_L_ElbowRotX', 'm_avg_L_ElbowRotY', 'm_avg_L_ElbowRotZ',
    'm_avg_L_WristRotX', 'm_avg_L_WristRotY', 'm_avg_L_WristRotZ',
    'm_avg_NeckRotX', 'm_avg_NeckRotY', 'm_avg_NeckRotZ',
    'm_avg_HeadRotX', 'm_avg_HeadRotY', 'm_avg_HeadRotZ',
    'm_avg_R_CollarRotX', 'm_avg_R_CollarRotY', 'm_avg_R_CollarRotZ',
    'm_avg_R_ShoulderRotX', 'm_avg_R_ShoulderRotY', 'm_avg_R_ShoulderRotZ',
    'm_avg_R_ElbowRotX', 'm_avg_R_ElbowRotY', 'm_avg_R_ElbowRotZ',
    'm_avg_R_WristRotX', 'm_avg_R_WristRotY', 'm_avg_R_WristRotZ',
    'Rot_diff_category'
]
# input 데이터(test_df)의 마지막 5 프레임과 
last_inputs_df = test_df.iloc[-30:][column_order].reset_index(drop=True)
test_predictions_df = pd.DataFrame(test_predictions_array, columns=column_order)

test_combined_df = pd.concat([last_inputs_df, test_predictions_df], ignore_index=True)

# %%
test_combined_df

# %%
test_combined_df.to_csv('./test_combined_df.csv', index=True)

# %% [markdown]
# # 추후 확인
# 1. Input 데이터 (combined_df)가 파일 한개 데이터 씩 순서 상관 없이 잘 섞였는지 확인
# 2. 학습 데이터를 IHSens 데이터로 하는게 맞는지? (다른 더 정확한 motion capture 데이터) 혹은 학습 시킬 때 position도 학습 시켜야 할지
# 3. 학습시킬 때, Transfromer에 넣기 전에 21개 skeletal 구조를 먼저 학습 시킨 후에 (어떤 모델로?) sequential한 motion 데이터를 학습 시켜야 하는지
#     - .bvh 파일 뷰어: https://www.creators3d.com/online-viewer

# %% [markdown]
# 두 모델에 넣는 데이터가 동일할 필요는 없습니다. 일반적으로 두 가지 방식에서 사용할 수 있는 데이터 전략은 다음과 같습니다:
#
# 같은 데이터 사용:
#
# CNN 모델을 통해 특징을 추출하고, 같은 데이터셋에 대한 이 특징을 Transformer 모델에 입력으로 사용합니다. 이 경우, Transformer 모델은 CNN 모델이 추출한 특징을 기반으로 추가적인 패턴을 학습합니다.
# 다른 데이터 사용:
#
# CNN 모델을 통해 특징을 추출할 때 사용한 데이터셋과는 다른, 새로운 데이터셋을 Transformer 모델에 입력으로 사용할 수 있습니다. 예를 들어, CNN 모델이 이미지의 특징을 추출하는 데 사용되었다면, Transformer 모델은 추출된 특징과 함께 다른 형태의 데이터(예: 텍스트 라벨 또는 시계열 데이터)를 사용하여 학습할 수 있습니다.
# 전이 학습:
#
# CNN 모델을 특정 작업에 대해 사전 훈련시키고(예: 이미지 분류), 추출된 특징을 다른 작업에 대한 Transformer 모델의 학습에 사용합니다(예: 이미지 캡셔닝). 이 경우 CNN은 일반적인 특징을 추출하고, Transformer는 특정 작업에 필요한 복잡한 관계를 학습합니다.
# 다단계 학습:
#
# CNN 모델로부터 얻은 특징을 이용해 첫 번째 단계의 Transformer 모델을 학습시킨 후, 그 결과를 두 번째 Transformer 모델에 입력으로 사용할 수도 있습니다. 이는 더 복잡한 시스템을 구축할 때 사용될 수 있으며, 각 단계는 서로 다른 종류의 추상화나 데이터 처리를 수행할 수 있습니다.
